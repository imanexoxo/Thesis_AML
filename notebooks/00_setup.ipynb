# %% [markdown]
# # Setup Iniziale - Importazione Librerie
#
# Questo notebook verifica che tutte le librerie funzionano.
# Esegui cella per cella.

# %% [markdown]
# ## 1. Librerie di Base

# %%
import os
import sys
import json
from pathlib import Path

print("✓ Librerie base")
# Out:
# ✓ Librerie base

# %% [markdown]
# ## 2. NumPy e Pandas

# %%
import numpy as np
import pandas as pd

print(f"✓ NumPy {np.__version__}")
print(f"✓ Pandas {pd.__version__}")
# Out:
# ✓ NumPy 2.4.4
# ✓ Pandas 3.0.3

# %% [markdown]
# ## 3. Scikit-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import sklearn

print(f"✓ Scikit-learn {sklearn.__version__}")
# Out:
# ✓ Scikit-learn 1.8.0

# %% [markdown]
# ## 4. Matplotlib e Seaborn

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %matplotlib inline

print(f"✓ Matplotlib {matplotlib.__version__}")
print(f"✓ Seaborn {sns.__version__}")
# Out:
# ✓ Matplotlib 3.10.9
# ✓ Seaborn 0.13.2

# %% [markdown]
# ## 5. PIL

# %%
from PIL import Image
import PIL

print(f"✓ PIL {PIL.__version__}")
# Out:
# ✓ PIL 12.2.0

# %% [markdown]
# ## 6. PyTorch e Torchvision

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms, models

print(f"✓ PyTorch {torch.__version__}")
print(f"✓ CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"  GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ✓ PyTorch 2.12.0+cu130
# ✓ CUDA: True
#   GPU: NVIDIA GeForce RTX 5090

# %% [markdown]
# ## 7. Utility

# %%
from tqdm import tqdm

print("✓ tqdm")
print("⚠ Kaggle (configureremo dopo)")
# Out:
# You must authenticate before you can call the Kaggle API.
# Please run "kaggle auth login" to log in via OAuth
# Or use one of the alternate ways to authenticate: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from tqdm import tqdm
# ----> 2 import kaggle
#       3
#       4 print("✓ tqdm")
#       5 print("✓ Kaggle")
#
# File ~/Thesis_AML/.venv/lib/python3.12/site-packages/kaggle/__init__.py:8
#       5 __version__ = "2.1.2"
#       7 api = KaggleApi()
# ----> 8 api.authenticate()
#
# File ~/Thesis_AML/.venv/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:966, in KaggleApi.authenticate(self)
#     962 print('Please run "kaggle auth login" to log in via OAuth')
#     963 print(
#     964     "Or use one of the alternate ways to authenticate: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication"
#     965 )
# --> 966 exit(1)
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## 8. Configurazione

# %%
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
PROJECT_ROOT = Path('..')

print(f"\n✓ Seed: {RANDOM_SEED}")
print(f"✓ Device: {device}")
print(f"✓ Project root: {PROJECT_ROOT}")
print("\n SETUP COMPLETATO!")
# Out:
# ✓ Seed: 42
# ✓ Device: cuda
# ✓ Project root: ..
#
#  SETUP COMPLETATO!
